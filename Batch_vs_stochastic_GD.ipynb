# %%
import numpy as np
import pandas as pd
import time

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df=df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
#X_train.shape

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 250 (1000.00 Byte)
# Trainable params: 250 (1000.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=250,validation_split=0.2)
#print(time.time() - start)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 201ms/step - loss: 0.5547 - accuracy: 0.7125 - val_loss: 0.8052 - val_accuracy: 0.3625
# Epoch 2/10
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5404 - accuracy: 0.7125 - val_loss: 0.7982 - val_accuracy: 0.3625
# Epoch 3/10
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5309 - accuracy: 0.7125 - val_loss: 0.7943 - val_accuracy: 0.3625
# Epoch 4/10
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5233 - accuracy: 0.7125 - val_loss: 0.7902 - val_accuracy: 0.3625
# Epoch 5/10
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5167 - accuracy: 0.7156 - val_loss: 0.7871 - val_accuracy: 0.3750
# Epoch 6/10
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5107 - accuracy: 0.7344 - val_loss: 0.7814 - val_accuracy: 0.4125
# Epoch 7/10
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5050 - accuracy: 0.7375 - val_loss: 0.7781 - val_accuracy: 0.4375
# Epoch 8/10
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4993 - accuracy: 0.7437 - val_loss: 0.7732 - val_accuracy: 0.4375
# Epoch 9/10
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4939 - accuracy: 0.7469 - val_loss: 0.7689 - val_accuracy: 0.4625
# Epoch 10/10
# 2/2 [==============================] - 0s 52ms/step - loss: 0.4888 - accuracy: 0.7500 - val_loss: 0.7654 - val_accuracy: 0.5125

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=10,batch_size=250,validation_split=0.2)
#print(time.time() - start)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 278ms/step - loss: 0.6338 - accuracy: 0.7125 - val_loss: 0.8644 - val_accuracy: 0.3625
# Epoch 2/10
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6190 - accuracy: 0.7125 - val_loss: 0.8567 - val_accuracy: 0.3625
# Epoch 3/10
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6094 - accuracy: 0.7125 - val_loss: 0.8498 - val_accuracy: 0.3625
# Epoch 4/10
# 2/2 [==============================] - 0s 41ms/step - loss: 0.6014 - accuracy: 0.7125 - val_loss: 0.8427 - val_accuracy: 0.3625
# Epoch 5/10
# 2/2 [==============================] - 0s 53ms/step - loss: 0.5938 - accuracy: 0.7125 - val_loss: 0.8379 - val_accuracy: 0.3625
# Epoch 6/10
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5869 - accuracy: 0.7125 - val_loss: 0.8324 - val_accuracy: 0.3625
# Epoch 7/10
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5805 - accuracy: 0.7125 - val_loss: 0.8274 - val_accuracy: 0.3625
# Epoch 8/10
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5746 - accuracy: 0.7125 - val_loss: 0.8247 - val_accuracy: 0.3625
# Epoch 9/10
# 2/2 [==============================] - 0s 64ms/step - loss: 0.5684 - accuracy: 0.7125 - val_loss: 0.8198 - val_accuracy: 0.3625
# Epoch 10/10
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5622 - accuracy: 0.7125 - val_loss: 0.8155 - val_accuracy: 0.3625

# %%
plt.plot(history.history['loss'])
